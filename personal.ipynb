# %% [markdown]
# <a href="https://colab.research.google.com/github/GarvinAgweli/Housepricingprediction/blob/main/personal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/housing.csv.zip")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X=data.drop(['median_house_value'],axis=1)
Y=data['median_house_value']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=False)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15610    -116.87     32.72                13.0       3268.0           491.0
# 12478    -121.48     38.59                52.0       1186.0           341.0
# 5996     -117.73     34.09                36.0       1543.0           297.0
# 11827    -121.02     39.01                17.0       4786.0           799.0
# 5183     -118.26     33.94                41.0       1510.0           410.0
# ...          ...       ...                 ...          ...             ...
# 13246    -117.63     34.12                 4.0       4323.0           775.0
# 19844    -119.09     36.42                17.0        877.0           219.0
# 9944     -122.26     38.16                23.0       2840.0           491.0
# 10908    -117.86     33.74                 9.0        525.0           171.0
# 2754     -115.49     32.67                24.0       1266.0           275.0
#
# ...

# %%
Y_train
# Out:
# 15610    259900.0
# 12478     70500.0
# 5996     117800.0
# 11827    185400.0
# 5183      94200.0
#            ...
# 13246    226800.0
# 19844     52500.0
# 9944     130400.0
# 10908    165300.0
# 2754      73100.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
data_1=X_train.join(Y_train)

# %%
data_1.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15610    -116.87     32.72                13.0       3268.0           491.0
# 12478    -121.48     38.59                52.0       1186.0           341.0
# 5996     -117.73     34.09                36.0       1543.0           297.0
# 11827    -121.02     39.01                17.0       4786.0           799.0
# 5183     -118.26     33.94                41.0       1510.0           410.0
#
#        population  households  median_income ocean_proximity  \
# 15610      1431.0       503.0         5.7652       <1H OCEAN
# 12478      1038.0       320.0         1.6116          INLAND
# 5996       1355.0       303.0         3.5313          INLAND
# 11827      2066.0       770.0         3.9734          INLAND
# 5183       1408.0       389.0         1.6500       <1H OCEAN
#
#        median_house_value
# 15610            259900.0
# 12478             70500.0
# 5996             117800.0
# 11827            185400.0
# ...

# %%
data_1.hist(figsize=(15,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data_1.corr()
# Out:
# <ipython-input-32-fa940e6684e6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_1.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924855           -0.108972     0.044112
# latitude            -0.924855  1.000000            0.012083    -0.037114
# housing_median_age  -0.108972  0.012083            1.000000    -0.358566
# total_rooms          0.044112 -0.037114           -0.358566     1.000000
# total_bedrooms       0.068264 -0.067702           -0.319112     0.929523
# population           0.098651 -0.108487           -0.292397     0.854883
# households           0.055665 -0.072715           -0.300634     0.919955
# median_income       -0.011551 -0.083271           -0.118274     0.199294
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_1.corr(),annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-36-07034714ee04>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_1.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
sns.pairplot(data_1)

# %%
plt.figure(figsize=(15,9))
sns.scatterplot(x='latitude',y='longitude',data=data_1,hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
data_1.ocean_proximity
# Out:
# 15610    <1H OCEAN
# 12478       INLAND
# 5996        INLAND
# 11827       INLAND
# 5183     <1H OCEAN
#            ...
# 13246       INLAND
# 19844       INLAND
# 9944      NEAR BAY
# 10908    <1H OCEAN
# 2754        INLAND
# Name: ocean_proximity, Length: 16346, dtype: object

# %%
pd.get_dummies(data_1.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 15610          1       0       0         0           0
# 12478          0       1       0         0           0
# 5996           0       1       0         0           0
# 11827          0       1       0         0           0
# 5183           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 13246          0       1       0         0           0
# 19844          0       1       0         0           0
# 9944           0       0       0         1           0
# 10908          1       0       0         0           0
# 2754           0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
data_1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15610    -116.87     32.72                13.0       3268.0           491.0
# 12478    -121.48     38.59                52.0       1186.0           341.0
# 5996     -117.73     34.09                36.0       1543.0           297.0
# 11827    -121.02     39.01                17.0       4786.0           799.0
# 5183     -118.26     33.94                41.0       1510.0           410.0
# ...          ...       ...                 ...          ...             ...
# 13246    -117.63     34.12                 4.0       4323.0           775.0
# 19844    -119.09     36.42                17.0        877.0           219.0
# 9944     -122.26     38.16                23.0       2840.0           491.0
# 10908    -117.86     33.74                 9.0        525.0           171.0
# 2754     -115.49     32.67                24.0       1266.0           275.0
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_1.corr(),annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-80-07034714ee04>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_1.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X=data.drop(['median_house_value'],axis=1)
Y=data['median_house_value']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=False)
X_train
Y_train
data_1=X_train.join(Y_train)
X_train,Y_train=data_1.drop(['median_house_value'],axis=1),data_1['median_house_value']
data_1.ocean_proximity
pd.get_dummies(data_1.ocean_proximity)
lr=LinearRegression
